# %%
y=int(input("输入年份："))
if y%4==0 and y%100!=0:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
import matplotlib.pyplot as plt
import numpy as np

# 绘制正弦曲线（图表直接显示在PyCharm内）
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))
plt.show()

# %% [markdown]
# 📖 Jupyter Notebook 的本质
# 它其实是一个智能的编程文档，可以理解为：
#
# [可以运行代码的PPT] + [实时画板] + [智能实验报告] 的结合体
# 🌟 和普通笔记本的6大区别
# 传统纸质/Word笔记本	Jupyter Notebook
# 只能写静态文字/贴图	可以运行代码并实时看到结果
# 公式需要手动计算	自动计算并展示数学公式/图表
# 修改内容会留痕迹	随时修改代码块重新运行
# 无法嵌入动态内容	支持插入交互式地图/3D模型/视频
# 单一文件格式	保存为.ipynb文件（包含代码+输出+图文）
# 无法版本控制	可以和Git配合管理修改历史
# 🎯 程序员/学生用它做什么？
# 数据分析：实时展示股票走势图
#
# python
# import yfinance as yf
# data = yf.download('AAPL', start='2023-01-01')
# data['Close'].plot()  # 直接显示股价曲线
# 机器学习教程：一步步演示训练过程
#
# python
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
# model.fit(X_train, y_train)  # 分步骤执行观察效果
# 课程作业：将代码、实验结果和思考写在一起
#
# markdown
# ## 实验目标
# 验证神经网络层数对准确率的影响
#
# ### 代码实现
# ```python
# model.add(Dense(units=64, activation='relu'))
# 结果分析
# 准确率从82%提升到89%...
#
#
# 科研论文：可重复的实验记录
#
# 🖥️ 实际界面演示
# 想象这样一个数字笔记本：
#
# |------------------------------|
# | [代码单元格]                  |
# | import numpy as np            |
# | print(np.sqrt(4))             |
# |------------------------------|
# | [输出结果]                    |
# | 2.0                          |
# |------------------------------|
# | [Markdown单元格]              |
# | **数学公式**：$$e^{i\pi}+1=0$$ |
# |------------------------------|
# | [图表输出]                    |
# | <显示一个动态生成的柱状图>     |
# |------------------------------|
# 💡 为什么AI课程推荐使用？
# 所见即所得：立即看到算法效果
# 降低学习门槛：可以分步骤执行复杂代码
# 报告一体化：代码、结果、分析同屏显示
# 便于分享：文件可以直接发给老师检查
# 📱 现代升级版
# Jupyter Lab：更强大的新一代界面（类似IDE）
# Jupyter Lab界面
#
# 现在当你说"做Notebook"时，其实是在创建一个可以交互的智能文档，而不是简单的文字记录。就像给你的代码装上了会说话的说明书！需要我展示具体操作过程吗？ 😊

# %% [markdown]
# 以下是Jupyter扩展和conda环境安装的区别详解，通过类比帮助你理解：
#
# 🌐 核心关系图示
# [VS Code Jupyter扩展] ← 用户界面 → [Jupyter包（conda环境）]
#        ｜                               ｜
#        ｜—— 提供编辑器功能 ——｜           ｜—— 实际执行代码 ——｜
# 📌 关键区别表
# VS Code Jupyter扩展	conda环境中的jupyter包
# 安装位置	安装在VS Code编辑器本身	安装在conda环境的Python中
# 功能定位	图形界面支持（.ipynb文件渲染、单元格操作）	计算引擎（代码执行、内核管理）
# 依赖关系	需要至少一个Python环境已安装jupyter包	独立安装，可存在多个版本
# 使用场景	编辑和运行Notebook的界面	实际运行Notebook代码的后端服务
# 多环境支持	通过切换内核连接不同conda环境	每个conda环境需要单独安装jupyter
# 🛠️ 正确配置流程
# 在conda环境安装jupyter包（必须）：
#
# bash
# conda activate ai_course
# conda install jupyter
# # 这会安装jupyter的核心组件（如notebook服务器、ipykernel等）
# VS Code安装Jupyter扩展（必须）：
#
# 扩展市场搜索安装"Jupyter"（Microsoft官方）
# 提供：.ipynb文件支持、单元格运行按钮、变量查看等功能
# 连接环境与扩展：
#
# 打开.ipynb文件后，右上角选择内核 → 选择ai_course环境
# 验证连接：
# python
# import sys
# print(sys.executable)  # 应显示.../anaconda3/envs/ai_course/...
# 💡 类比理解
# 餐厅比喻：
#
# Jupyter扩展 → 点餐平板（界面交互）
# conda中的jupyter → 厨房设备（实际做菜）
# 汽车比喻：
#
# **扩展 [Network Error]
#
#
#
# 2025/2/24 13:59:32
#
#
# pycharm和Vscode有什么区别，老师让我们下载pycharm
#
# 2025/2/24 14:02:06
#
#
# 好的，我现在需要回答用户关于PyCharm和VS Code区别的问题，考虑到老师让他们下载PyCharm，但用户之前在使用VS Code和Anaconda。我需要详细解释两者的区别，同时保持中立，帮助用户理解为什么老师可能推荐PyCharm，但同时也说明VS Code的优势，让用户可以根据需求选择。
#
# 首先，用户可能是一个刚开始学习Python的学生，对工具不太熟悉，可能需要明确的对比。我需要分点列出它们的区别，比如定位、功能、性能、配置难度、适用场景等。还要注意用户之前已经在使用VS Code和Anaconda，可能需要指导如何在两者之间切换或配合使用。
#
# 要确保信息准确，避免偏见，比如虽然PyCharm功能全面，但VS Code更轻量且扩展性强。同时，老师可能推荐PyCharm是因为它的集成度更高，适合教学统一，但学生可能有自己的偏好。需要指出PyCharm的专业版和社区版区别，特别是对于数据科学或Web开发是否需要专业版功能。
#
# 另外，用户可能对配置环境不太熟悉，所以需要说明PyCharm的环境管理方式，与Anaconda的结合使用，以及和VS Code的不同之处。可能还需要给出建议，比如对初学者来说PyCharm可能更简单，而VS Code更灵活，适合有一定经验后使用。
#
# 还要考虑用户之前的问题中已经设置了Anaconda环境，所以需要说明PyCharm如何利用现有的conda环境，避免重复配置。可能还需要比较两者的调试功能、插件生态、资源占用情况，特别是对于学生可能使用的硬件配置。
#
# 最后，总结建议，尊重老师的推荐，同时让用户知道可以根据自己的需求和喜好选择工具，或者两者并用。可能需要提醒用户，工具只是手段，学习编程概念更重要，但选择合适的工具能提升效率。
#
# 以下是PyCharm与VS Code的详细对比分析，帮助你理解二者的区别和适用场景：
#
# 📊 核心差异对比表
# 特性	PyCharm（专业版）	VS Code
# 定位	专业Python IDE	轻量级通用编辑器+IDE功能
# 开箱体验	预装Python开发全套工具	需手动安装扩展搭建环境
# 资源占用	较高（约1GB内存）	较低（约300MB内存）
# 智能补全	深度代码分析，准确率高	依赖扩展，部分场景稍逊
# 调试功能	可视化调试器，支持Django等框架	需配置launch.json，但足够常用
# 数据库支持	内置数据库工具	需安装SQL扩展
# 科学计算	专业版有Data View等高级功能	通过Jupyter扩展实现
# 多语言支持	侧重Python，其他语言支持有限	通过扩展支持几乎所有语言
# 配置复杂度	自动配置环境	需自行配置解释器和扩展
# 价格	专业版收费（学生可免费申请）	完全免费
# 🎓 老师推荐PyCharm的潜在原因
# 统一教学环境：避免学生环境配置出现问题
# 深度学习集成：专业版的科学模式适合AI课程
# 更准确的代码提示：对Python语法分析更精准
# 项目管理便利：内置的工程文件结构适合教学
# 调试可视化：学生更易理解程序执行流程
# ✅ PyCharm使用建议（结合你的现有环境）
# 关联Anaconda环境：
#
# 新建项目时选择"Existing interpreter"
# 路径指向：.../anaconda3/envs/ai_course/python.exe
# 保留VS Code的场景：
#
# 快速编辑文本/配置文件
# 需要同时处理多种语言文件时
# 轻量级Jupyter Notebook编写
# 教学适配配置：
#
# File → Settings → Project:xxx → Python Interpreter → 添加Conda环境
# 🆚 典型使用场景对比
# 使用PyCharm更好：
#
# 开发Django/Flask Web应用
# 进行复杂代码重构
# 深度学习模型调试
# 团队协作开发
# 使用VS Code更好：
#
# 快速编辑Markdown笔记
# 前端开发（HTML/CSS/JS）
# 多语言混合项目
# 轻量级脚本编写
# 💻 硬件要求参考
# 设备配置	推荐工具	理由
# 4GB内存老旧笔记本	VS Code	更节省系统资源
# 16GB内存游戏本	PyCharm专业版	能充分发挥IDE优势
# Mac M1	两者均可	优化良好，根据需求选择
# 🔄 共存使用方案
# 主次搭配：
#
# PyCharm用于课程作业
# VS Code用于日常笔记/小脚本
# 共享环境配置：
#
# bash
# # 在PyCharm Terminal中验证
# conda activate ai_course
# python -c "import torch; print(torch.__cuda_version__)"
# 项目互操作：
#
# 在PyCharm创建的项目，可用VS Code打开编辑
# 通过Git进行版本管理保持同步
# 📝 选型建议
# 遵循课程要求：先用PyCharm完成作业
# 逐渐尝试VS Code：了解不同工具的优劣
# 核心原则：
# 🛠️ PyCharm快速入门步骤
# 下载PyCharm Community（免费版）
# 新建项目时选择Existing interpreter → 添加你的ai_course环境
# 创建main.py测试：
# python
# if __name__ == "__main__":
#     print("Hello PyCharm!")
# 右键运行 → 观察控制台输出
# 两种工具就像「瑞士军刀」和「专业厨刀」的关系，建议先按老师要求使用PyCharm，后期根据实际需求灵活选择。需要PyCharm的具体使用教程吗？ 😊

# %%
# 第一个单元格输入
import sys
print(sys.executable)  # 应显示ai_course环境路径
# Out:
# D:\Own_Download\Anaconda\envs\ai_python_course\python.exe
